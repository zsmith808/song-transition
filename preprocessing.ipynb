# %% [markdown]
# AI song transition project

# %%
# !pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio==0.8.1 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install -r requirements.txt
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      ---------------------------------------- 0.0/3.1 GB ? eta -:--:--
#      ---------------------------------------- 0.0/3.1 GB 83.9 MB/s eta 0:00:37
#      ---------------------------------------- 0.0/3.1 GB 84.5 MB/s eta 0:00:36
#       --------------------------------------- 0.1/3.1 GB 81.4 MB/s eta 0:00:37
#       --------------------------------------- 0.1/3.1 GB 76.7 MB/s eta 0:00:39
#      - -------------------------------------- 0.1/3.1 GB 77.9 MB/s eta 0:00:39
#      - -------------------------------------- 0.1/3.1 GB 75.6 MB/s eta 0:00:40
#      - -------------------------------------- 0.1/3.1 GB 73.7 MB/s eta 0:00:40
#      - -------------------------------------- 0.1/3.1 GB 73.0 MB/s eta 0:00:41
#      - -------------------------------------- 0.1/3.1 GB 72.1 MB/s eta 0:00:41
#      - -------------------------------------- 0.1/3.1 GB 68.1 MB/s eta 0:00:43
# ...
